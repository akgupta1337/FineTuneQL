# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
from peft import prepare_model_for_kbit_training
from peft import LoraConfig, get_peft_model
from datasets import load_dataset
import transformers

# %%
model_name = "TheBloke/Mistral-7B-Instruct-v0.2-GPTQ"
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",  # automatically figures out how to best use CPU + GPU for loading model
    trust_remote_code=False,  # prevents running custom model files on your machine
    revision="main",  # which version of model to use in repo
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 2
#       1 model_name = "TheBloke/Mistral-7B-Instruct-v0.2-GPTQ"
# ----> 2 model = AutoModelForCausalLM.from_pretrained(
#       3     model_name,
#       4     device_map="auto",  # automatically figures out how to best use CPU + GPU for loading model
#       5     trust_remote_code=False,  # prevents running custom model files on your machine
#       6     revision="main",  # which version of model to use in repo
#       7 )
#
# File ~/akhil/nlp/omega/lib/python3.13/site-packages/transformers/models/auto/auto_factory.py:573, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     571 elif type(config) in cls._model_mapping.keys():
#     572     model_class = _get_model_class(config, cls._model_mapping)
# --> 573     return model_class.from_pretrained(
#     574         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     575     )
#     576 raise ValueError(
#     577     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     578     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     579 )
#
# File ~/akhil/nlp/omega/lib/python3.13/site-packages/transformers/modeling_utils.py:272, in restore_default_torch_dtype.<locals>._wrapper(*args, **kwargs)
#     270 old_dtype = torch.get_default_dtype()
#     271 try:
# --> 272     return func(*args, **kwargs)
#     273 finally:
#     274     torch.set_default_dtype(old_dtype)
#
# File ~/akhil/nlp/omega/lib/python3.13/site-packages/transformers/modeling_utils.py:4292, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4289     hf_quantizer = None
#    4291 if hf_quantizer is not None:
# -> 4292     hf_quantizer.validate_environment(
#    4293         torch_dtype=torch_dtype,
#    4294         from_tf=from_tf,
#    4295         from_flax=from_flax,
#    4296         device_map=device_map,
#    4297         weights_only=weights_only,
#    4298     )
#    4299     torch_dtype = hf_quantizer.update_torch_dtype(torch_dtype)
#    4300     device_map = hf_quantizer.update_device_map(device_map)
#
# File ~/akhil/nlp/omega/lib/python3.13/site-packages/transformers/quantizers/quantizer_gptq.py:67, in GptqHfQuantizer.validate_environment(self, *args, **kwargs)
#      65     raise RuntimeError("GPU is required to quantize or run quantize model.")
#      66 elif not (is_auto_gptq_available() or is_gptqmodel_available()):
# ---> 67     raise ImportError(
#      68         "Loading a GPTQ quantized model requires gptqmodel (`pip install gptqmodel`) or auto-gptq (`pip install auto-gptq`) library. "
#      69     )
#      70 elif is_auto_gptq_available() and version.parse(importlib.metadata.version("auto_gptq")) < version.parse(
#      71     "0.4.2"
#      72 ):
#      73     raise ImportError(
#      74         "You need a version of auto_gptq >= 0.4.2 to use GPTQ: `pip install --upgrade auto-gptq` or use gptqmodel by `pip install gptqmodel>=1.4.3`."
#      75     )
#
# ImportError: Loading a GPTQ quantized model requires gptqmodel (`pip install gptqmodel`) or auto-gptq (`pip install auto-gptq`) library.

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True)

# %%
# !pip install -v gptqmodel --no-build-isolation
# Out:
# Using pip 25.0.1 from /home/Necromancer/akhil/nlp/omega/lib/python3.13/site-packages/pip (python 3.13)
# Collecting gptqmodel
#   Using cached gptqmodel-2.1.0.tar.gz (280 kB)
#   Preparing metadata (pyproject.toml) ...   Running command Preparing metadata (pyproject.toml)
#   conda_cuda_include_dir /home/Necromancer/akhil/nlp/omega/lib/python3.13/site-packages/nvidia/cuda_runtime/include
#   appending conda cuda include dir /home/Necromancer/akhil/nlp/omega/lib/python3.13/site-packages/nvidia/cuda_runtime/include
#   Traceback (most recent call last):
#     File "/home/Necromancer/akhil/nlp/omega/lib/python3.13/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 389, in <module>
#       main()
#       ~~~~^^
#     File "/home/Necromancer/akhil/nlp/omega/lib/python3.13/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 373, in main
#       json_out["return_val"] = hook(**hook_input["kwargs"])
#                                ~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#     File "/home/Necromancer/akhil/nlp/omega/lib/python3.13/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 175, in prepare_metadata_for_build_wheel
#       return hook(metadata_directory, config_settings)
#     File "/home/Necromancer/akhil/nlp/omega/lib/python3.13/site-packages/setuptools/build_meta.py", line 377, in prepare_metadata_for_build_wheel
#       self.run_setup()
#       ~~~~~~~~~~~~~~^^
#     File "/home/Necromancer/akhil/nlp/omega/lib/python3.13/site-packages/setuptools/build_meta.py", line 522, in run_setup
#       super().run_setup(setup_script=setup_script)
#       ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "/home/Necromancer/akhil/nlp/omega/lib/python3.13/site-packages/setuptools/build_meta.py", line 320, in run_setup
#       exec(code, locals())
#       ~~~~^^^^^^^^^^^^^^^^
#     File "<string>", line 225, in <module>
#     File "/home/Necromancer/akhil/nlp/omega/lib/python3.13/site-packages/torch/utils/cpp_extension.py", line 1078, in CUDAExtension
#       library_dirs += library_paths(cuda=True)
#                       ~~~~~~~~~~~~~^^^^^^^^^^^
#     File "/home/Necromancer/akhil/nlp/omega/lib/python3.13/site-packages/torch/utils/cpp_extension.py", line 1209, in library_paths
#       if (not os.path.exists(_join_cuda_home(lib_dir)) and
#                              ~~~~~~~~~~~~~~~^^^^^^^^^
#     File "/home/Necromancer/akhil/nlp/omega/lib/python3.13/site-packages/torch/utils/cpp_extension.py", line 2416, in _join_cuda_home
#       raise OSError('CUDA_HOME environment variable is not set. '
#                     'Please set it to your CUDA install root.')
#   OSError: CUDA_HOME environment variable is not set. Please set it to your CUDA install root.
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   full command: /home/Necromancer/akhil/nlp/omega/bin/python /home/Necromancer/akhil/nlp/omega/lib/python3.13/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py prepare_metadata_for_build_wheel /tmp/tmp3188x69q
#   cwd: /tmp/pip-install-h_zzorbf/gptqmodel_53798605475244b4849ee3a718d35feb
# error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
